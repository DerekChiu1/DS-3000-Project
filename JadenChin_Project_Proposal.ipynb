# %% [markdown]
# # Project 1 Proposal
#
# ### Understanding Concert Venues and Events
#
# ### Jaden Chin, DS3000

# %% [markdown]
# ## Introduction
# Live events are a large source of entertainment and attraction all over the world. Whether it be sports games or concerts, they attract thousands of people to venues of different sizes to experience these events. I want to study the diversity of live events in major cities in the U.S and answer questions of what types of events are most popular and create most revenue. I am also interested in answering the question of what types of venues host certain events and are typically more expensive. There are also multiple questions that are similar that I hope to answer in my studies.i
#
# ## Data Collection
# I plan to use the ticketmaster API in order to collect the data on events in major cities in the U.S. Ticketmaster is one of the largest ticket selling companies that offers a variety of events. I use it to query data for every event in a certain state and give it a specific time range for the events I am looking for I did need to sign up for api key in order to access the ability to request.

# %%
import requests
import json
import pandas as pd
from datetime import datetime

def get_events(state, start_date, end_date):
    """Uses Ticketmaster API to query concert data and create a dataframe of event information
    
    Args:
        state (str): desired state 
        start_date (str): start date
        end_date (str): end date of search

    Returns:
        df_events (DataFrame): dataframe containing specified events and their details
    """
    # url used to query as well as api key
    url = 'https://app.ticketmaster.com/discovery/v2/events.json'
    api_key = 'TM0JuNjaXxkse0u8OzG1EQc49ZdUVtVz'

    # formats start and end date to datetime
    start_datetime = f'{start_date}T00:00:00Z'
    end_datetime = f'{end_date}T00:00:00Z'

    # parameters for the api request
    params = {
        'apikey': api_key,
        'stateCode': state,
        'startDateTime': start_datetime,
        'endDateTime': end_datetime,
        'size': 200, 
    }

    # create empty dataframe for all events
    df_events = pd.DataFrame()

    #queries data using url and parameters
    response = requests.get(url, params=params)

    # converts the response to dictionary
    data = response.json()

    # extracts from dictionary
    events = data["_embedded"]["events"]

    #loops through each event
    for event in events:
            
        # checks for price ranges and returns none if its not there
        if 'priceRanges' in event:
            min_price = event['priceRanges'][0]['min']
            max_price = event['priceRanges'][0]['max']
        else:
            min_price = None
            max_price = None

        # create the series for the relevant data we want
        event_series = pd.Series({
            "name": event["name"],
            "event_date": event["dates"]["start"]["localDate"],
            "status": event['dates']['status']['code'],
            "venue": event['_embedded']['venues'][0]['name'],
            "city": event['_embedded']['venues'][0]['city']['name'],
            "event_type": event['classifications'][0]['segment']['name'],
            "genre": event['classifications'][0]['genre']['name'], 
            "price_range": (min_price, max_price)
        })

        # append series into empty dataframe
        df_events = pd.concat([df_events, event_series.to_frame().T], ignore_index=True)

    return df_events

# %%
events200 = get_events("MA", "2024-01-01", "2024-12-31")

# %%
events200.head(50)
# Out:
#                                                  name  event_date   status  \
# 0                Boston Bruins vs. Montreal Canadiens  2024-10-10   onsale
# 1                 Boston Bruins vs. Los Angeles Kings  2024-10-12   onsale
# 2     Banner Night: Boston Celtics v. New York Knicks  2024-10-22   onsale
# 3                  Boston Bruins vs. Florida Panthers  2024-10-14   onsale
# 4     Preseason: Boston Celtics v. Philadelphia 76ers  2024-10-12   onsale
# 5                   Boston Bruins vs. St. Louis Blues  2024-11-16   onsale
# 6                   Boston Bruins vs. Ottawa Senators  2024-11-09   onsale
# 7                    Boston Bruins vs. Seattle Kraken  2024-11-03   onsale
# 8                Boston Bruins vs. Montreal Canadiens  2024-12-01   onsale
# 9               Boston Bruins vs. Philadelphia Flyers  2024-10-29   onsale
# 10              Boston Bruins vs. Pittsburgh Penguins  2024-11-29   onsale
# 11                      The The - Ensouled World Tour  2024-10-19   onsale
# 12  The Spinners - Evelyn Champagne King - Rose Royce  2024-11-09   onsale
# 13              Boston Bruins vs. Philadelphia Flyers  2024-12-07   onsale
# 14                Boston Bruins vs. Vancouver Canucks  2024-11-26   onsale
# 15                   Boston Bruins vs. Calgary Flames  2024-11-07   onsale
# 16                Boston Bruins vs. Detroit Red Wings  2024-12-03   onsale
# 17            Boston Bruins vs. Columbus Blue Jackets  2024-12-28   onsale
# 18                   Boston Bruins vs. Buffalo Sabres  2024-12-21   onsale
# 19                 Boston Bruins vs. Utah Hockey Club  2024-11-21   onsale
# 20            Boston Bruins vs. Columbus Blue Jackets  2024-11-18   onsale
# 21       Preseason: Boston Celtics v. Toronto Raptors  2024-10-13   onsale
# 22                 Boston Celtics vs. Milwaukee Bucks  2024-10-28   onsale
# 23           Boston Celtics vs. Golden State Warriors  2024-11-06   onsale
# 24              Boston Bruins vs. Toronto Maple Leafs  2024-10-26   onsale
# 25                   Boston Celtics vs. Brooklyn Nets  2024-11-08   onsale
# 26          Boston Celtics vs. Minnesota Timberwolves  2024-11-24   onsale
# 27                 Boston Celtics vs. Toronto Raptors  2024-11-16   onsale
# 28              Boston Celtics vs. Philadelphia 76ers  2024-12-25   onsale
# 29                   Boston Celtics vs. Atlanta Hawks  2024-11-12   onsale
# 30                  Boston Celtics vs. Indiana Pacers  2024-12-27   onsale
# 31                     Boston Celtics vs. LA Clippers  2024-11-25   onsale
# 32                 Boston Celtics vs. Milwaukee Bucks  2024-12-06   onsale
# 33                      Boston Celtics vs. Miami Heat  2024-12-02   onsale
# 34             Boston Celtics vs. Cleveland Cavaliers  2024-11-19   onsale
# 35                  Boston Celtics vs. Indiana Pacers  2024-12-29   onsale
# 36               Boston Celtics vs. Memphis Grizzlies  2024-12-07   onsale
# 37                   Boston Celtics vs. Chicago Bulls  2024-12-19   onsale
# 38              Boston Bruins vs. Washington Capitals  2024-12-23   onsale
# 39                 Boston Celtics vs. Detroit Pistons  2024-12-04   onsale
# 40                     Boston Bruins vs. Dallas Stars  2024-10-24   onsale
# 41            New England Patriots vs. Miami Dolphins  2024-10-06  offsale
# 42                               New England Patriots  2024-10-13  offsale
# 43             New England Patriots vs. New York Jets  2024-10-27  offsale
# 44          New England Patriots vs. Los Angeles Rams  2024-11-17  offsale
# 45        New England Patriots vs. Indianapolis Colts  2024-12-01  offsale
# 46      BILLIE EILISH: HIT ME HARD AND SOFT: THE TOUR  2024-10-11   onsale
# 47          Sebastian Maniscalco: It Ain't Right Tour  2024-10-04   onsale
# 48  Gracie Abrams: The Secret of Us Tour with spec...  2024-10-09   onsale
# 49          Sebastian Maniscalco: It Ain't Right Tour  2024-10-05   onsale
#
#                                     venue        city      event_type  \
# 0                               TD Garden      Boston          Sports
# 1                               TD Garden      Boston          Sports
# 2                               TD Garden      Boston          Sports
# 3                               TD Garden      Boston          Sports
# 4                               TD Garden      Boston          Sports
# 5                               TD Garden      Boston          Sports
# 6                               TD Garden      Boston          Sports
# 7                               TD Garden      Boston          Sports
# 8                               TD Garden      Boston          Sports
# 9                               TD Garden      Boston          Sports
# 10                              TD Garden      Boston          Sports
# 11  Orpheum Theatre presented by Citizens      Boston           Music
# 12                        Lynn Auditorium        Lynn           Music
# 13                              TD Garden      Boston          Sports
# 14                              TD Garden      Boston          Sports
# 15                              TD Garden      Boston          Sports
# 16                              TD Garden      Boston          Sports
# 17                              TD Garden      Boston          Sports
# 18                              TD Garden      Boston          Sports
# 19                              TD Garden      Boston          Sports
# 20                              TD Garden      Boston          Sports
# 21                              TD Garden      Boston          Sports
# 22                              TD Garden      Boston          Sports
# 23                              TD Garden      Boston          Sports
# 24                              TD Garden      Boston          Sports
# 25                              TD Garden      Boston          Sports
# 26                              TD Garden      Boston          Sports
# 27                              TD Garden      Boston          Sports
# 28                              TD Garden      Boston          Sports
# 29                              TD Garden      Boston          Sports
# 30                              TD Garden      Boston          Sports
# 31                              TD Garden      Boston          Sports
# 32                              TD Garden      Boston          Sports
# 33                              TD Garden      Boston          Sports
# 34                              TD Garden      Boston          Sports
# 35                              TD Garden      Boston          Sports
# 36                              TD Garden      Boston          Sports
# 37                              TD Garden      Boston          Sports
# 38                              TD Garden      Boston          Sports
# 39                              TD Garden      Boston          Sports
# 40                              TD Garden      Boston          Sports
# 41                       Gillette Stadium  Foxborough          Sports
# 42                       Gillette Stadium  Foxborough          Sports
# 43                       Gillette Stadium  Foxborough          Sports
# 44                       Gillette Stadium  Foxborough          Sports
# 45                       Gillette Stadium  Foxborough          Sports
# 46                              TD Garden      Boston           Music
# 47                              TD Garden      Boston  Arts & Theatre
# 48               MGM Music Hall at Fenway      Boston           Music
# 49                              TD Garden      Boston  Arts & Theatre
#
#          genre      price_range
# 0       Hockey  (140.0, 1565.5)
# 1       Hockey  (120.0, 1565.5)
# 2   Basketball  (319.5, 5285.5)
# 3       Hockey   (95.0, 1565.5)
# 4   Basketball   (62.5, 1115.5)
# 5       Hockey  (141.0, 1565.5)
# 6       Hockey  (156.0, 1565.5)
# 7       Hockey  (121.0, 1565.5)
# 8       Hockey  (231.0, 1565.5)
# 9       Hockey   (81.0, 1565.5)
# 10      Hockey  (216.0, 1565.5)
# 11        Rock    (39.5, 125.0)
# 12         R&B    (47.0, 107.0)
# 13      Hockey  (181.0, 1565.5)
# 14      Hockey  (106.0, 1565.5)
# 15      Hockey  (101.0, 1565.5)
# 16      Hockey  (106.0, 1565.5)
# 17      Hockey  (216.0, 1565.5)
# 18      Hockey  (181.0, 1565.5)
# 19      Hockey   (91.0, 1565.5)
# 20      Hockey   (91.0, 1565.5)
# 21  Basketball   (52.5, 1006.5)
# 22  Basketball   (98.5, 3505.5)
# 23  Basketball  (150.5, 3485.5)
# 24      Hockey  (181.0, 1565.5)
# 25  Basketball   (92.5, 3605.5)
# 26  Basketball  (133.5, 3065.5)
# 27  Basketball   (60.5, 1885.5)
# 28  Basketball  (221.5, 3505.5)
# 29  Basketball   (71.5, 1065.5)
# 30  Basketball  (165.5, 5405.5)
# 31  Basketball   (86.5, 5405.5)
# 32  Basketball  (134.5, 6305.5)
# 33  Basketball   (90.5, 4405.5)
# 34  Basketball   (87.5, 1525.5)
# 35  Basketball  (155.5, 6305.5)
# 36  Basketball  (152.5, 6305.5)
# 37  Basketball   (98.5, 5505.5)
# 38      Hockey  (181.0, 1565.5)
# 39  Basketball   (55.5, 3825.5)
# 40      Hockey   (91.0, 1565.5)
# 41    Football   (120.0, 390.0)
# 42    Football   (160.0, 420.0)
# 43    Football   (180.0, 500.0)
# 44    Football   (140.0, 420.0)
# 45    Football   (120.0, 360.0)
# 46         Pop    (59.5, 499.5)
# 47      Comedy    (59.5, 309.5)
# 48        Rock     (39.5, 89.5)
# 49      Comedy    (49.5, 300.0)

# %% [markdown]
# ## Data Collection and Remaining Issues
# The data above contains a lot of categorical data including the name, venue, genre as well as the status of the event. I also included the price ranges as well of tickets for the event. I plan to use this data to see which events have the most expensive price ranges as well as which genres do. I am still trying to figure out how to deal with missing data and how to return it with None value. Additionally I am trying to figure out how to fetch more events as the max I could do is 200 events. I hope to either do this using either pagination or by doing something similar to hw2 and doing it in month periods. This has limited me to only be able to look at one state at a time. With the data, I hope to count how many events of each genre are hosted at each venue to see the distribution of variety as well as look at the prices of each event what venues are most expensive. I hope to use supervised learning models in order to predict things like predicting what venues will host what events. I hope to also use regression to predict prices of tickets in the futre for certain venues or genres.
